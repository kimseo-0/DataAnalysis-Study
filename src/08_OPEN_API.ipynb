# %% [markdown]
# # OPEN API

# %% [markdown]
# ```
# uv add requests
# uv add python-dotenv
# ```

# %% [markdown]
# # 1. 공공데이터포털 OPEN API

# %% [markdown]
# ## 1) API KEY 불러오기

# %%
# 1. .env 파일에 PUBLIC_DATA_API_KEY = "인증키 입력"을 입력한 후 저장
# 2. .env 파일에 있는 내용 불러오기
from dotenv import load_dotenv
import os

load_dotenv()
print(os.getenv("PUBLIC_DATA_API_KEY"))
# Out:
# PNIg2tn4W8O4L%2BggITS2EnatwGEOcqh%2BF2BpIbyUYihNM43JHge0DIgjLJ5JRKJOfvKIv9GzTOYtY7R6J9dTtw%3D%3D

# %% [markdown]
# ## 2) URL 만들기

# %% [markdown]
# ### 방법1

# %%
# 3. requests 요청
base_url = "http://apis.data.go.kr/B552061/frequentzoneLgrViolt/getRestFrequentzoneLgrViolt"

serviceKey = os.getenv("PUBLIC_DATA_API_KEY")
searchYearCd = 2017
siDo = 11
guGun = 680
n_type = "json"
numOfRows = 100
pageNo = 1

url = f"{base_url}?serviceKey={serviceKey}&searchYearCd={searchYearCd}&siDo={siDo}&guGun={guGun}&type={n_type}&numOfRows={numOfRows}&pageNo={pageNo}"
print(url)
# Out:
# http://apis.data.go.kr/B552061/frequentzoneLgrViolt/getRestFrequentzoneLgrViolt?serviceKey=PNIg2tn4W8O4L%2BggITS2EnatwGEOcqh%2BF2BpIbyUYihNM43JHge0DIgjLJ5JRKJOfvKIv9GzTOYtY7R6J9dTtw%3D%3D&searchYearCd=2017&siDo=11&guGun=680&type=json&numOfRows=100&pageNo=1

# %%
import requests 
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
print(response.json())
# Out:
# {"resultCode":"00","resultMsg":"NORMAL_CODE","items":{"item":[{"afos_fid":6423519,"afos_id":"01","bjd_cd":"1168010100","spot_cd":"11680001","sido_sgg_nm":"서울특별시 강남구1","spot_nm":"서울특별시 강남구 역삼동(역삼역 부근)","occrrnc_cnt":9,"caslt_cnt":13,"dth_dnv_cnt":0,"se_dnv_cnt":4,"sl_dnv_cnt":7,"wnd_dnv_cnt":2,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[127.03780003,37.50074789],[127.03778277,37.50060885],[127.03773165,37.50047516],[127.03764864,37.50035195],[127.03753692,37.50024395],[127.03740079,37.50015532],[127.03724548,37.50008946],[127.03707697,37.5000489],[127.03690171,37.50003521],[127.03672646,37.5000489],[127.03655794,37.50008946],[127.03640264,37.50015532],[127.03626651,37.50024395],[127.03615479,37.50035195],[127.03607178,37.50047516],[127.03602066,37.50060885],[127.0360034,37.50074789],[127.03602066,37.50088692],[127.03607178,37.50102061],[127.03615479,37.50114383],[127.03626651,37.50125182],[127.03640264,37.50134045],[127.03655794,37.50140631],[127.03672646,37.50144686],[127.0
# ...

# %% [markdown]
# ### 방법2

# %%
base_url = "http://apis.data.go.kr/B552061/frequentzoneLgrViolt/getRestFrequentzoneLgrViolt"

params = {
    "ServiceKey": os.getenv("PUBLIC_DATA_API_KEY_DE"),
    "searchYearCd": 2017,
    "siDo": 11,
    "guGun": 680,
    "type": "json",
    "numOfRows": 100,
    "pageNo": 1
}

import requests
response = requests.get(base_url, params=params)
print(response.text)
# Out:
# <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>
# 		<returnReasonCode>30</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_ServiceResponse>

# %%
keyword = "컴퓨터"
url = f"www.example.com/keyword=컴퓨터" # XXXXX 컴퓨터 인코딩해야한다.

params = {
    "keyword": "컴퓨터"
}

# %% [markdown]
# ## 3) 데이터 파악하기

# %%
response_text = response.text
print(response_text)
print(type(response_text))
# "{"A": 0, "B": 1, "C": 2}"
print(response_text["resultCode"])
# Out:
# <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>
# 		<returnReasonCode>30</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_ServiceResponse>
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 print(type(response_text))
#       4 # "{"A": 0, "B": 1, "C": 2}"
# ----> 5 print(response_text["resultCode"])
#
# TypeError: string indices must be integers, not 'str'

# %%
response_json = response.json()
print(response_json)
print(type(response_json))
print(response_json["resultCode"])
# Out:
# {'resultCode': '00', 'resultMsg': 'NORMAL_CODE', 'items': {'item': [{'afos_fid': 6423519, 'afos_id': '01', 'bjd_cd': '1168010100', 'spot_cd': '11680001', 'sido_sgg_nm': '서울특별시 강남구1', 'spot_nm': '서울특별시 강남구 역삼동(역삼역 부근)', 'occrrnc_cnt': 9, 'caslt_cnt': 13, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 4, 'sl_dnv_cnt': 7, 'wnd_dnv_cnt': 2, 'geom_json': '{"type":"Polygon","coordinates":[[[127.03780003,37.50074789],[127.03778277,37.50060885],[127.03773165,37.50047516],[127.03764864,37.50035195],[127.03753692,37.50024395],[127.03740079,37.50015532],[127.03724548,37.50008946],[127.03707697,37.5000489],[127.03690171,37.50003521],[127.03672646,37.5000489],[127.03655794,37.50008946],[127.03640264,37.50015532],[127.03626651,37.50024395],[127.03615479,37.50035195],[127.03607178,37.50047516],[127.03602066,37.50060885],[127.0360034,37.50074789],[127.03602066,37.50088692],[127.03607178,37.50102061],[127.03615479,37.50114383],[127.03626651,37.50125182],[127.03640264,37.50134045],[127.03655794,37.50140631],[127.036
# ...

# %%
# (미션) response_json의 키는 총 몇 개 인가요?
# (미션) response_json의 키들은 무슨 의미를 갖고 있나요?
# (미션) items키의 값의 type은 무엇인가요?
# (미션) items키의 item 안에는 어떤 값이 들어있나요?

# %%
test_dict = {"가": {"A": 1}, "나": 1, "다": 0}
print(test_dict.keys())
print(test_dict["가"]["A"])
# Out:
# dict_keys(['가', '나', '다'])
# 1

# %%
response_json
# Out:
# {'resultCode': '00',
#  'resultMsg': 'NORMAL_CODE',
#  'items': {'item': [{'afos_fid': 6423519,
#     'afos_id': '01',
#     'bjd_cd': '1168010100',
#     'spot_cd': '11680001',
#     'sido_sgg_nm': '서울특별시 강남구1',
#     'spot_nm': '서울특별시 강남구 역삼동(역삼역 부근)',
#     'occrrnc_cnt': 9,
#     'caslt_cnt': 13,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 4,
#     'sl_dnv_cnt': 7,
#     'wnd_dnv_cnt': 2,
# ...

# %%
response_json.keys()
# resultCode: 결과 코드
# resultMsg: 결과 메세지
# items
# totalCount: 총건수
# numOfRows: 검색 건수
# pageNo: 페이지 번호
# Out:
# dict_keys(['resultCode', 'resultMsg', 'items', 'totalCount', 'numOfRows', 'pageNo'])

# %%
item_value = response_json["items"]["item"] # 리스트
item_value
# Out:
# [{'afos_fid': 6423519,
#   'afos_id': '01',
#   'bjd_cd': '1168010100',
#   'spot_cd': '11680001',
#   'sido_sgg_nm': '서울특별시 강남구1',
#   'spot_nm': '서울특별시 강남구 역삼동(역삼역 부근)',
#   'occrrnc_cnt': 9,
#   'caslt_cnt': 13,
#   'dth_dnv_cnt': 0,
#   'se_dnv_cnt': 4,
#   'sl_dnv_cnt': 7,
#   'wnd_dnv_cnt': 2,
# ...

# %%
for item in item_value:
    print(item)
# Out:
# {'afos_fid': 6423519, 'afos_id': '01', 'bjd_cd': '1168010100', 'spot_cd': '11680001', 'sido_sgg_nm': '서울특별시 강남구1', 'spot_nm': '서울특별시 강남구 역삼동(역삼역 부근)', 'occrrnc_cnt': 9, 'caslt_cnt': 13, 'dth_dnv_cnt': 0, 'se_dnv_cnt': 4, 'sl_dnv_cnt': 7, 'wnd_dnv_cnt': 2, 'geom_json': '{"type":"Polygon","coordinates":[[[127.03780003,37.50074789],[127.03778277,37.50060885],[127.03773165,37.50047516],[127.03764864,37.50035195],[127.03753692,37.50024395],[127.03740079,37.50015532],[127.03724548,37.50008946],[127.03707697,37.5000489],[127.03690171,37.50003521],[127.03672646,37.5000489],[127.03655794,37.50008946],[127.03640264,37.50015532],[127.03626651,37.50024395],[127.03615479,37.50035195],[127.03607178,37.50047516],[127.03602066,37.50060885],[127.0360034,37.50074789],[127.03602066,37.50088692],[127.03607178,37.50102061],[127.03615479,37.50114383],[127.03626651,37.50125182],[127.03640264,37.50134045],[127.03655794,37.50140631],[127.03672646,37.50144686],[127.03690171,37.50146056],[127.03707697,37.50144
# ...

# %% [markdown]
# ## 4) 데이터프레임 만들기

# %%
import pandas as pd

data = pd.DataFrame(response_json["items"]["item"])
data
# Out:
#     afos_fid afos_id      bjd_cd   spot_cd sido_sgg_nm  \
# 0    6423519      01  1168010100  11680001  서울특별시 강남구1
# 1    6423685      01  1168010600  11680002  서울특별시 강남구2
# 2    6423402      01  1168010100  11680003  서울특별시 강남구3
# 3    6423999      01  1168010100  11680004  서울특별시 강남구4
# 4    6423498      01  1168010500  11680005  서울특별시 강남구5
# 5    6423385      01  1168010500  11680006  서울특별시 강남구6
# 6    6423441      01  1168010100  11680007  서울특별시 강남구7
# 7    6424000      01  1168011500  11680008  서울특별시 강남구8
# 8    6424126      01  1168010100  11680009  서울특별시 강남구9
# 9    6424335      02  1168011800  11680001  서울특별시 강남구1
# 10   6424337      02  1168010800  11680002  서울특별시 강남구2
# 11   6424336      02  1168010100  11680003  서울특별시 강남구3
#
#                       spot_nm  occrrnc_cnt  caslt_cnt  dth_dnv_cnt  \
# 0       서울특별시 강남구 역삼동(역삼역 부근)            9         13            0
# 1      서울특별시 강남구 대치동(학여울역 부근)            8         12            0
# ...

# %% [markdown]
# ## 5) 데이터 저장하기

# %%
data.to_csv("data/한국도로교통공단_법규위반별 교통사고 다발지역 정보.csv")

# %% [markdown]
# # 2. 서울열린광장포털 OPENAPI
#
# > 인용구 추가

# %% [markdown]
# ## 1) API KEY 불러오기

# %%
from dotenv import load_dotenv

load_dotenv()
print(os.getenv("SEOUL_PUBLIC_API_KEY"))
# Out:
# 73707758476e61723739706d414246

# %% [markdown]
# ## 2) URL 만들기

# %%
# 샘플 URL: http://openapi.seoul.go.kr:8088/(인증키)/json/tbCycleStationInfo/1/5/

base_url = "http://openapi.seoul.go.kr:8088"

# 요청 파라미터
key = os.getenv("SEOUL_PUBLIC_API_KEY")
type_n = "json"
service = "tbCycleStationInfo"
start_index = 1
end_index = 10

# url 만들기
url = f"{base_url}/{key}/{type_n}/{service}/{start_index}/{end_index}"
print(url)
# Out:
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/1/10

# %%
import requests

response = requests.get(url)
print(response.text)
# Out:
# {"stationInfo":{"list_total_count":"3171","RESULT":{"CODE":"INFO-000","MESSAGE":"정상 처리되었습니다."},"row":[{"STA_LOC":"마포구","RENT_ID":"ST-10","RENT_NO":"00108","RENT_NM":"서교동 사거리","RENT_ID_NM":"108. 서교동 사거리","HOLD_NUM":"12","STA_ADD1":"서울특별시 마포구 양화로 93","STA_ADD2":"427","STA_LAT":"37.55274582","STA_LONG":"126.91861725","START_INDEX":0,"END_INDEX":0,"RNUM":"1"},{"STA_LOC":"광진구","RENT_ID":"ST-100","RENT_NO":"00503","RENT_NM":"더샵스타시티 C동 앞","RENT_ID_NM":"503. 더샵스타시티 C동 앞","HOLD_NUM":"15","STA_ADD1":"서울특별시 광진구 아차산로 262","STA_ADD2":"더샵스타시티 C동 앞","STA_LAT":"37.53666687","STA_LONG":"127.07359314","START_INDEX":0,"END_INDEX":0,"RNUM":"2"},{"STA_LOC":"양천구","RENT_ID":"ST-1000","RENT_NO":"00729","RENT_NM":"서부식자재마트 건너편","RENT_ID_NM":"729. 서부식자재마트 건너편","HOLD_NUM":"10","STA_ADD1":"서울특별시 양천구 신정동 236 ","STA_ADD2":"서부식자재마트 건너편","STA_LAT":"37.51037979","STA_LONG":"126.86679840","START_INDEX":0,"END_INDEX":0,"RNUM":"3"},{"STA_LOC":"양천구","RENT_ID":"ST-1002","RENT_NO":"00731","RENT_NM":"서울시 도로환경관리센터","RENT_ID_
# ...

# %%
response_json = response.json()
response_json
# Out:
# {'stationInfo': {'list_total_count': '3171',
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#   'row': [{'STA_LOC': '마포구',
#     'RENT_ID': 'ST-10',
#     'RENT_NO': '00108',
#     'RENT_NM': '서교동 사거리',
#     'RENT_ID_NM': '108. 서교동 사거리',
#     'HOLD_NUM': '12',
#     'STA_ADD1': '서울특별시 마포구 양화로 93',
#     'STA_ADD2': '427',
#     'STA_LAT': '37.55274582',
#     'STA_LONG': '126.91861725',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '1'},
#    {'STA_LOC': '광진구',
#     'RENT_ID': 'ST-100',
#     'RENT_NO': '00503',
#     'RENT_NM': '더샵스타시티 C동 앞',
#     'RENT_ID_NM': '503. 더샵스타시티 C동 앞',
#     'HOLD_NUM': '15',
#     'STA_ADD1': '서울특별시 광진구 아차산로 262',
#     'STA_ADD2': '더샵스타시티 C동 앞',
#     'STA_LAT': '37.53666687',
#     'STA_LONG': '127.07359314',
#     'START_INDEX': 0,
#     'END_INDEX': 0,
#     'RNUM': '2'},
#    {'STA_LOC': '양천구',
#     'RENT_ID': 'ST-1000',
#     'RENT_NO': '00729',
#     'RENT_NM': '서부식자재마트 건너편',
# ...

# %% [markdown]
# ## 3) 데이터 파악하기

# %%
response_json.keys()
# Out:
# dict_keys(['stationInfo'])

# %%
response_json["stationInfo"]
# Out:
# {'list_total_count': '3171',
#  'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#  'row': [{'STA_LOC': '마포구',
#    'RENT_ID': 'ST-10',
#    'RENT_NO': '00108',
#    'RENT_NM': '서교동 사거리',
#    'RENT_ID_NM': '108. 서교동 사거리',
#    'HOLD_NUM': '12',
#    'STA_ADD1': '서울특별시 마포구 양화로 93',
#    'STA_ADD2': '427',
#    'STA_LAT': '37.55274582',
#    'STA_LONG': '126.91861725',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '1'},
#   {'STA_LOC': '광진구',
#    'RENT_ID': 'ST-100',
#    'RENT_NO': '00503',
#    'RENT_NM': '더샵스타시티 C동 앞',
#    'RENT_ID_NM': '503. 더샵스타시티 C동 앞',
#    'HOLD_NUM': '15',
#    'STA_ADD1': '서울특별시 광진구 아차산로 262',
#    'STA_ADD2': '더샵스타시티 C동 앞',
#    'STA_LAT': '37.53666687',
#    'STA_LONG': '127.07359314',
#    'START_INDEX': 0,
#    'END_INDEX': 0,
#    'RNUM': '2'},
#   {'STA_LOC': '양천구',
#    'RENT_ID': 'ST-1000',
#    'RENT_NO': '00729',
#    'RENT_NM': '서부식자재마트 건너편',
#    'RENT_ID_NM': '729. 서부식자재마트 건너편',
#    'HOLD_NUM': '10',
# ...

# %%
response_json["stationInfo"].keys()
# Out:
# dict_keys(['list_total_count', 'RESULT', 'row'])

# %%
response_json["stationInfo"]["row"]
# Out:
# [{'STA_LOC': '마포구',
#   'RENT_ID': 'ST-10',
#   'RENT_NO': '00108',
#   'RENT_NM': '서교동 사거리',
#   'RENT_ID_NM': '108. 서교동 사거리',
#   'HOLD_NUM': '12',
#   'STA_ADD1': '서울특별시 마포구 양화로 93',
#   'STA_ADD2': '427',
#   'STA_LAT': '37.55274582',
#   'STA_LONG': '126.91861725',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '1'},
#  {'STA_LOC': '광진구',
#   'RENT_ID': 'ST-100',
#   'RENT_NO': '00503',
#   'RENT_NM': '더샵스타시티 C동 앞',
#   'RENT_ID_NM': '503. 더샵스타시티 C동 앞',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 광진구 아차산로 262',
#   'STA_ADD2': '더샵스타시티 C동 앞',
#   'STA_LAT': '37.53666687',
#   'STA_LONG': '127.07359314',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '2'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1000',
#   'RENT_NO': '00729',
#   'RENT_NM': '서부식자재마트 건너편',
#   'RENT_ID_NM': '729. 서부식자재마트 건너편',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 신정동 236 ',
#   'STA_ADD2': '서부식자재마트 건너편',
#   'STA_LAT': '37.51037979',
#   'STA_LONG': '126.86679840',
#   'START_INDEX': 0,
# ...

# %% [markdown]
# ## 4) 데이터프레임 만들기

# %%
data_list = response_json["stationInfo"]["row"]

import pandas as pd

data = pd.DataFrame(data_list)
data
# Out:
#   STA_LOC  RENT_ID RENT_NO       RENT_NM         RENT_ID_NM HOLD_NUM  \
# 0     마포구    ST-10   00108       서교동 사거리       108. 서교동 사거리       12
# 1     광진구   ST-100   00503   더샵스타시티 C동 앞   503. 더샵스타시티 C동 앞       15
# 2     양천구  ST-1000   00729   서부식자재마트 건너편   729. 서부식자재마트 건너편       10
# 3     양천구  ST-1002   00731  서울시 도로환경관리센터  731. 서울시 도로환경관리센터       10
# 4     양천구  ST-1003   00732         신월중학교         732. 신월중학교       10
# 5     양천구  ST-1004   00733   신정이펜하우스314동   733. 신정이펜하우스314동       10
# 6     양천구  ST-1005   00734      신트리공원 입구      734. 신트리공원 입구       10
# 7     양천구  ST-1006   00735        영도초등학교        735. 영도초등학교       10
# 8     양천구  ST-1007   00736         오솔길공원         736. 오솔길공원       10
# 9     양천구  ST-1008   00737          장수공원          737. 장수공원       20
#
#                       STA_ADD1      STA_ADD2      STA_LAT      STA_LONG  \
# 0             서울특별시 마포구 양화로 93           427  37.55274582  126.91861725
# ...

# %% [markdown]
# ## 5) 데이터 많이 불러오기

# %%
# 샘플 URL: http://openapi.seoul.go.kr:8088/(인증키)/json/tbCycleStationInfo/1/5/

base_url = "http://openapi.seoul.go.kr:8088"

# 요청 파라미터
key = os.getenv("SEOUL_PUBLIC_API_KEY")
type_n = "json"
service = "tbCycleStationInfo"
start_index = 1
end_index = 3171

# url 만들기
url = f"{base_url}/{key}/{type_n}/{service}/{start_index}/{end_index}"
print(url)
# Out:
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/1/3171

# %%
import requests

response = requests.get(url)
print(response.text)
# Out:
# <RESULT><CODE>ERROR-336</CODE><MESSAGE><![CDATA[데이터요청은 한번에 최대 1000건을 넘을 수 없습니다.
# 요청종료위치에서 요청시작위치를 뺀 값이 1000을 넘지 않도록 수정하세요.]]></MESSAGE></RESULT>

# %%
for start in range(1, 3002, 1000):
    end = start + 1000 - 1
    print(start, end)
# Out:
# 1 1000
# 1001 2000
# 2001 3000
# 3001 4000

# %%
for start in range(1, 4001, 1000):
    end = start + 1000 - 1
    print(start, end)
# Out:
# 1 1000
# 1001 2000
# 2001 3000
# 3001 4000

# %%
# 0 ~ 999
# 1000 ~ 1999
# 2000 ~ 2999
# 3000 ~ 3171

# 1 ~ 1000
# 1001 ~ 2000
# 2001 ~ 3000
# 3001 ~ 4000
base_url = "http://openapi.seoul.go.kr:8088"

# 요청 파라미터
key = os.getenv("SEOUL_PUBLIC_API_KEY")
type_n = "json"
service = "tbCycleStationInfo"

# 0. 빈 리스트를 만든다.(total_data)
# 1. start가 0, 1000, 2000, 3000
# 2. end를 만든다. end = start + 1000 - 1
# 3. url을 만든다.
# 4. 요청을 한다
# 5. 데이터 리스트를 파싱한다. data_list
# 6. total_data에 data_list를 합친다. ---- extend
# 7. total_data를 pd.DataFrame()을 이용해서 데이터프레임을 만든다.
total_data = []
for start in range(0, 3001, 1000):
    end = start + 1000 - 1

    url = f"{base_url}/{key}/{type_n}/{service}/{start}/{end}"
    print(url)
    response = requests.get(url)
    response_json = response.json()
    data_list = response_json["stationInfo"]["row"]
    print(len(data_list))
    total_data.extend(data_list)
# Out:
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/0/999
# 999
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/1000/1999
# 1000
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/2000/2999
# 1000
# http://openapi.seoul.go.kr:8088/73707758476e61723739706d414246/json/tbCycleStationInfo/3000/3999
# 172

# %%
total_data
# Out:
# [{'STA_LOC': '마포구',
#   'RENT_ID': 'ST-10',
#   'RENT_NO': '00108',
#   'RENT_NM': '서교동 사거리',
#   'RENT_ID_NM': '108. 서교동 사거리',
#   'HOLD_NUM': '12',
#   'STA_ADD1': '서울특별시 마포구 양화로 93',
#   'STA_ADD2': '427',
#   'STA_LAT': '37.55274582',
#   'STA_LONG': '126.91861725',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '1'},
#  {'STA_LOC': '광진구',
#   'RENT_ID': 'ST-100',
#   'RENT_NO': '00503',
#   'RENT_NM': '더샵스타시티 C동 앞',
#   'RENT_ID_NM': '503. 더샵스타시티 C동 앞',
#   'HOLD_NUM': '15',
#   'STA_ADD1': '서울특별시 광진구 아차산로 262',
#   'STA_ADD2': '더샵스타시티 C동 앞',
#   'STA_LAT': '37.53666687',
#   'STA_LONG': '127.07359314',
#   'START_INDEX': 0,
#   'END_INDEX': 0,
#   'RNUM': '2'},
#  {'STA_LOC': '양천구',
#   'RENT_ID': 'ST-1000',
#   'RENT_NO': '00729',
#   'RENT_NM': '서부식자재마트 건너편',
#   'RENT_ID_NM': '729. 서부식자재마트 건너편',
#   'HOLD_NUM': '10',
#   'STA_ADD1': '서울특별시 양천구 신정동 236 ',
#   'STA_ADD2': '서부식자재마트 건너편',
#   'STA_LAT': '37.51037979',
#   'STA_LONG': '126.86679840',
#   'START_INDEX': 0,
# ...

# %%
import pandas as pd

data = pd.DataFrame(total_data)
data
# Out:
#      STA_LOC  RENT_ID RENT_NO                  RENT_NM  \
# 0        마포구    ST-10   00108                  서교동 사거리
# 1        광진구   ST-100   00503              더샵스타시티 C동 앞
# 2        양천구  ST-1000   00729              서부식자재마트 건너편
# 3        양천구  ST-1002   00731             서울시 도로환경관리센터
# 4        양천구  ST-1003   00732                    신월중학교
# ...      ...      ...     ...                      ...
# 3166     양천구   ST-993   00722  경서농협 버스정류장(우리은행신정동지점방향)
# 3167     양천구   ST-994   00723                   SBS방송국
# 3168     양천구   ST-995   00724          계남공원 입구 주출입구 좌측
# 3169     양천구   ST-996   00725               양강중학교앞 교차로
# 3170     양천구   ST-997   00726            목동3단지 시내버스정류장
#
#                         RENT_ID_NM HOLD_NUM                     STA_ADD1  \
# 0                     108. 서교동 사거리       12             서울특별시 마포구 양화로 93
# 1                 503. 더샵스타시티 C동 앞       15           서울특별시 광진구 아차산로 262
# 2                 729. 서부식자재마트 건너편       10           서울특별시 양천구 신정동 236
# ...

# %% [markdown]
# # 3. Naver API

# %% [markdown]
# ## 1) 샘플 코드

# %% [markdown]
# ### 원본

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "YOUR_CLIENT_ID"
client_secret = "YOUR_CLIENT_SECRET"
encText = urllib.parse.quote("검색할 단어")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# ### 원본 변형

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

# 1. 정보 입력
client_id = "kAE0Dk30fVkzEjZDaN_K"
client_secret = "M7M9dtvaAf"

# 2. 키워드 입력
keyword = "인공지능"

# 3. 키워드 인코딩하기
encText = urllib.parse.quote(keyword)
# print(keyword)
# print(encText)

# 4. URL 만들기
url = "https://openapi.naver.com/v1/search/news.json?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

# 5. 데이터 요청 준비
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

# 6. 데이터 요청
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 22 Jul 2025 14:45:43 +0900",
# 	"total":3084318,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"“中企의 기술력·디자인 기업의 창의력 결합 땐 시너지… 디자인으로 ...",
# 			"originallink":"https:\/\/www.chosun.com\/special\/special_section\/2025\/07\/22\/MN7XZ5PEXBBEJIDAHWBCNBYRA4\/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/023\/0003918621?sid=004",
# 			"description":"예를 들어 <b>인공지능<\/b>(AI) 플랫폼 스타트업 래블업(LABLUP)은 디자인 기업 바이스 버사와 협업해 디자인 시스템 및 정보 구조를 정비했습니다. 이를 통해 기업 고객의 UI(사용자 연결 장치) 완결성을 획기적으로 높여 ‘래블업... ",
# 			"pubDate":"Tue, 22 Jul 2025 14:44:00 +0900"
# 		},
# 		{
# 			"title":"NIA-국립국악원, 국악 생성 AI 데이터 구축 협력",
# 			"originallink":"https:\/\/www.koit.co.kr\/news\/articleView.html?idxno=200860",
# 			"link":"https:\/\/www.koit.co.kr\/news\/articleView.html?idxno=200860",
# ...

# %% [markdown]
# ## 2) requests 활용

# %%
# 네이버 검색 API 예제 - 블로그 검색
import requests
import urllib
import os
from dotenv import load_dotenv
load_dotenv()

# 1. 정보 입력
client_id = os.getenv("NAVER_CLIENT_ID")
client_secret = os.getenv("NAVER_CLIENT_SECRET")

# 2. 키워드 입력
keyword = "인공지능"

# 3. 키워드 인코딩하기
encText = urllib.parse.quote(keyword)
# print(keyword)
# print(encText)

# 4. URL 만들기
base_url = "https://openapi.naver.com/v1/search/news.json"
query = encText

url = f"{base_url}?query={query}"

# 5. 데이터 요청
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}
response = requests.get(url, headers=headers)
if response.status_code == 200:
    print(response.json())
else:
    print("Error")
# Out:
# {'lastBuildDate': 'Tue, 22 Jul 2025 15:07:02 +0900', 'total': 3084406, 'start': 1, 'display': 10, 'items': [{'title': '[현장] LG, AI 주권 강조…&quot;엑사원으로 산업도, 생태계도 바꾼다&quot;', 'originallink': 'http://www.biztribune.co.kr/news/articleView.html?idxno=337358', 'link': 'http://www.biztribune.co.kr/news/articleView.html?idxno=337358', 'description': "LG AI연구원이 자체 <b>인공지능</b> 생태계 '엑사원(EXAONE)'을 중심으로 산업 전환에 속도를 내고 있다. 22일 서울 강서구 마곡 LG사이언스파크에서 열린 'LG AI 토크 콘서트 2025'에서 LG AI연구원은 차세대 AI 모델과 기업형... ", 'pubDate': 'Tue, 22 Jul 2025 15:06:00 +0900'}, {'title': '팩토리얼 CEO &quot;전고체 배터리, 자동차 넘어 항공우주로…현대차 협력 강...', 'originallink': 'https://www.theguru.co.kr/news/article.html?no=89650', 'link': 'https://www.theguru.co.kr/news/article.html?no=89650', 'description': "팩토리얼은 배터리 개발 효율성을 높이기 위해 <b>인공지능</b>(AI) 기반 디지털 트윈 플랫폼 '감마트론(Gammatron)'을 개발해 활용 중이다. 이 플랫폼을 통해 배터리 수명 예측을 수개월에서 단 1~2주 이내로 단축했고, 새로운... ", 'pubDate': 'Tue, 22 Jul 2025 15:06:00 +0900'}, {'title': '&quot;트럼프가 발표한 690조원 AI 프로젝트, 6개월째 제자리&quot;', '
# ...

# %% [markdown]
# ## 3) requests 활용 2

# %%
# 네이버 검색 API 예제 - 블로그 검색
import requests
import os
from dotenv import load_dotenv
load_dotenv()

# 1. 정보 입력
client_id = os.getenv("NAVER_CLIENT_ID")
client_secret = os.getenv("NAVER_CLIENT_SECRET")

# 2. 키워드 입력
keyword = "인공지능"

# 3. 파라미터 만들기
params = {
    "query": keyword,
    "display": 3,
    "start": 1,
    "sort": "date"
}

# 4. URL 만들기
base_url = "https://openapi.naver.com/v1/search/news.json"

# 5. 데이터 요청
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}
response = requests.get(url, headers=headers, params=params)
if response.status_code == 200:
    response_json = response.json()
    print(response.json())
else:
    print("Error")
# Out:
# {'lastBuildDate': 'Tue, 22 Jul 2025 15:28:32 +0900', 'total': 3084500, 'start': 1, 'display': 3, 'items': [{'title': '넥쏘, 수소차 최초로 국제행사 의전차량 데뷔', 'originallink': 'http://www.segye.com/newsView/20250722512673?OutUrl=naver', 'link': 'https://n.news.naver.com/mnews/article/022/0004053787?sid=101', 'description': 'APEC 에너지장관회의는 다음달 27일부터 28일까지 부산 파라다이스 호텔 및 누리마루에서 개최되며, 총 21개 경제체가 모여 전력망 인프라 및 에너지 안보 강화, 안정적인 전력공급, <b>인공지능</b>(AI)을 활용한 에너지 혁신... ', 'pubDate': 'Tue, 22 Jul 2025 15:27:00 +0900'}, {'title': "[주니어전자]포항공대, 국내 최초로 마이크로소프트와 'AI-네이티브 대학...", 'originallink': 'https://www.etnews.com/20250722000371', 'link': 'https://n.news.naver.com/mnews/article/030/0003334078?sid=102', 'description': "포스텍(포항공대)이 국내 대학 가운데 처음으로 마이크로소프트(MS)와 함께 '<b>인공지능</b>-네이티브 대학(AI-Native University)' 현실화하기로 했어요. 'AI-네이티브 대학'은 대학이 학사행정에 부분적으로 AI를 도입하는 것과는... ", 'pubDate': 'Tue, 22 Jul 2025 15:27:00 +0900'}, {'title': '조용익 부천시장 “이재명 정부가 AI 전환 시대에 발맞춰 추진하고 있는...', 'originallink': 'https://www.cnbnews.com/news/arti
# ...

# %%
for a in response_json["items"]:
    print(a["title"])
# Out:
# 넥쏘, 수소차 최초로 국제행사 의전차량 데뷔
# [주니어전자]포항공대, 국내 최초로 마이크로소프트와 'AI-네이티브 대학...
# 조용익 부천시장 “이재명 정부가 AI 전환 시대에 발맞춰 추진하고 있는...

# %%
# 네이버 검색 API 예제 - 블로그 검색
import requests
import os
from dotenv import load_dotenv
load_dotenv()

# 1. 정보 입력
client_id = os.getenv("NAVER_CLIENT_ID")
client_secret = os.getenv("NAVER_CLIENT_SECRET")

# 2. 키워드 입력
keyword = "인공지능"

# 3. 파라미터 만들기
params = {
    "query": keyword,
    "display": 3,
    "start": 2,
    "sort": "sim"
}

# 4. URL 만들기
base_url = "https://openapi.naver.com/v1/search/news.json"

# 5. 데이터 요청
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}
response = requests.get(url, headers=headers, params=params)
print(response.text)
if response.status_code == 200:
    response_json = response.json()
    print(response.json())
else:
    print("Error")
# Out:
# {
# 	"lastBuildDate":"Tue, 22 Jul 2025 15:35:30 +0900",
# 	"total":3084533,
# 	"start":2,
# 	"display":3,
# 	"items":[
# 		{
# 			"title":"&quot;AI 바이오 세계 1강 도전&quot;…배경훈 과기장관, 첫 행보로 바이오 현장찾...",
# 			"originallink":"https:\/\/www.newsis.com\/view\/NISX20250721_0003260550",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/003\/0013376184?sid=103",
# 			"description":"&quot;<b>인공지능<\/b>(AI) 3대 강국을 넘어 특히 AI 바이오 분야만큼은 세계 1강을 목표로 도전하겠습니다.&quot; 배경훈 과학기술정보통신부 장관이 21일 취임 후 첫 현장 일정으로 바이오 스타트업이 밀집한 서울바이오허브를 찾아 이같이... ",
# 			"pubDate":"Mon, 21 Jul 2025 17:30:00 +0900"
# 		},
# 		{
# 			"title":"LG전자의 <b>인공지능<\/b> 생태계 '엑사원'",
# 			"originallink":"https:\/\/www.news1.kr\/photos\/7406293",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/421\/0008384536?sid=101",
# 			"description":"임우형 LG AI연구원 공동연구원장이 22일 오전 서울 강서구 마곡 LG사이언스파크 컨버전스홀에서 열린 'LG AI 토크 콘서트 2025'에서 엑사원(EXAONE) 생태계를 소개하고 있다. LG AI연구원은 이날 의료, 데이터... ",
# 			"pubDate":"Tue, 22 Jul 2025 10:58:00 +0900"
# 		},
# 		{
# ...

# %%
for a in response_json["items"]:
    print(a["title"])
# Out:
# [주니어전자]포항공대, 국내 최초로 마이크로소프트와 'AI-네이티브 대학...
# &quot;새 공장 조속히 건립&quot;... SPC, '변화와 혁신 추진단' 첫 회의 진행
# 경기도교육청율곡연수원, ' '2026년 연수운영계획 수립 전략회의' 개최...

# %% [markdown]
# # 4. YouTube API

# %% [markdown]
# ```
# uv add google-api-python-client
# ```

# %%
# 유튜브 댓글을 수집하는 함수
from googleapiclient.discovery import build 
import pandas as pd
import os 
from dotenv import load_dotenv 
load_dotenv()

api_key = os.getenv("YOUTUBE_API_KEY")
video_id = "7qXFLRRMbKw"

youtube = build("youtube", "v3", developerKey=api_key)

comments = []
next_page_token = None 

while True:
    response = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,
        pageToken=next_page_token,
        textFormat="plainText"
    ).execute()

    for item in response["items"]:
        comment = item["snippet"]["topLevelComment"]["snippet"]
        comments.append(
            {
                "author": comment["authorDisplayName"],
                "text": comment["textDisplay"],
                "likeCount": comment["likeCount"],
                "publishedAt": comment["publishedAt"]
            }
        )

    next_page_token = response.get("nextPageToken")
    if not next_page_token:
        break 

data = pd.DataFrame(comments)
data.head()
# Out:
#       author                                               text  likeCount  \
# 0   @소그미-k2s  지구 온난화가 심해지고 있다는 게 체감되네요 더운 날씨에 모두들 건강 조심하시길 바...          0
# 1  @Hyuk-t7u                                            존나 시원한데          0
# 2    @kwersh                하나도 못 맞추노 ㅋㅋㅋㅋ 장마 또 시작했구먼 세금낭비다,,,,          0
# 3   @노홍철-m1b                                               아츠이나          0
# 4   @보리수-b1h                       다른나라 더. 더워. 우리나라 양호한거여. 기상청아          0
#
#             publishedAt
# 0  2025-07-21T06:04:55Z
# 1  2025-07-20T04:00:39Z
# 2  2025-07-18T11:39:46Z
# 3  2025-07-18T11:38:58Z
# 4  2025-07-15T01:30:33Z

# %%
# 네이버 검색 API 예제 - 블로그 검색
import requests
import os
from dotenv import load_dotenv
load_dotenv()

# 정보 입력
client_id = os.getenv("NAVER_CLIENT_ID")
client_secret = os.getenv("NAVER_CLIENT_SECRET")

# 키워드 입력
keyword = "인공지능"

# 파라미터 만들기
# query    String    Y    검색어. UTF-8로 인코딩되어야 합니다.
# display    Integer    N    한 번에 표시할 검색 결과 개수(기본값: 10, 최댓값: 100)
# start    Integer    N    검색 시작 위치(기본값: 1, 최댓값: 1000)
# sort    String    N    검색 결과 정렬 방법
# sim: 정확도순으로 내림차순 정렬(기본값)
# date: 날짜순으로 내림차순 정렬
params = {
    "query": keyword,
    "display": 100,
    "start": 10,
    "sort": "date"
}

# 파라미터 만들기
params = {
"query": keyword,
"display": 100
}
# URL 만들기
base_url = "https://openapi.naver.com/v1/search/news.json"


# 데이터 요칭
headers ={
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}

n = 0
while n < 10:
    response = requests.get(url, headers=headers, params=params)
    print(response.text)
    n += 1
# Out:
# {"resultCode":"00","resultMsg":"NORMAL_CODE","items":{"item":[{"afos_fid":6423519,"afos_id":"01","bjd_cd":"1168010100","spot_cd":"11680001","sido_sgg_nm":"서울특별시 강남구1","spot_nm":"서울특별시 강남구 역삼동(역삼역 부근)","occrrnc_cnt":9,"caslt_cnt":13,"dth_dnv_cnt":0,"se_dnv_cnt":4,"sl_dnv_cnt":7,"wnd_dnv_cnt":2,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[127.03780003,37.50074789],[127.03778277,37.50060885],[127.03773165,37.50047516],[127.03764864,37.50035195],[127.03753692,37.50024395],[127.03740079,37.50015532],[127.03724548,37.50008946],[127.03707697,37.5000489],[127.03690171,37.50003521],[127.03672646,37.5000489],[127.03655794,37.50008946],[127.03640264,37.50015532],[127.03626651,37.50024395],[127.03615479,37.50035195],[127.03607178,37.50047516],[127.03602066,37.50060885],[127.0360034,37.50074789],[127.03602066,37.50088692],[127.03607178,37.50102061],[127.03615479,37.50114383],[127.03626651,37.50125182],[127.03640264,37.50134045],[127.03655794,37.50140631],[127.03672646,37.50144686],[127.0
# ...
